# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
df_data = pd.read_excel('../data/NIC-UD_Bloomberg_Data.xlsx', index_col=0)

# %% [markdown]
# All

# %%
df_data
# Out:
#             USGG10YR Index  USGG2YR Index  USGG3M Index  SPX Index  \
# Dates
# 1990-01-01          7.9350            NaN           NaN        NaN
# 1990-01-02          7.9300         7.8750        7.8090   360.5678
# 1990-01-03          7.9740         7.9270        7.8610   359.6426
# 1990-01-04          7.9720         7.9100        7.8280   356.6984
# 1990-01-05          7.9840         7.8850        7.7810   353.2264
# 1990-01-08          8.0120         7.8930        7.7480   354.8511
# 1990-01-09          8.0090         7.8930        7.7890   350.6726
# 1990-01-10          8.0140         7.8760        7.7460   348.3596
# 1990-01-11          8.0440         7.9200        7.7970   349.5833
# 1990-01-12          8.0960         7.9380        7.7160   341.0165
# 1990-01-15          8.1130         7.9470        7.7160   338.0771
# 1990-01-16          8.1960         8.0980        7.8620   341.8552
# 1990-01-17          8.1910         8.0540        7.9350   338.5074
# ...

# %% [markdown]
# # Study Apple stock

# %% [markdown]
# Individual stock: Apple (AAPL UW Equity)

# %%
df_apple = df_data["AAPL UW Equity"]
df_apple.head()
# Out:
# Dates
# 1990-01-01       NaN
# 1990-01-02    1.3304
# 1990-01-03    1.3393
# 1990-01-04    1.3438
# 1990-01-05    1.3482
# Name: AAPL UW Equity, dtype: float64

# %% [markdown]
# Plot it

# %%
df_apple.plot()
